# %%
import urllib.request
import datetime
from dateutil.relativedelta import relativedelta
import os

# %%
start_url = "http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst"
coord = "[(1.1):1:(11)][(129):1:(136.4)]"

# %%
start = datetime.date(1979, 1, 1) 
end = datetime.date(2023,5,31)

# "[(1979-01-01):1:(1980-01-01)]"
prev = None
while (start <= end):
    
    prev = start
    start += relativedelta(months=+1)
    if start > end:
        break
    time = "[(" + prev.strftime("%Y-%m-%d") + "):1:(" + start.strftime("%Y-%m-%d") + ")]"
    print(start_url + time + coord)
    urllib.request.urlretrieve(start_url + time + coord,
                           "./CFS/hawaii_soest_7889_5330_7085?ocnsst" + time + ".nc")
    
time = "[(" + prev.strftime("%Y-%m-%d") + "):1:(" + "2023-05-31T23:00:00Z" + ")]"
print(start_url + time + coord)
urllib.request.urlretrieve(start_url + time + coord,
                           "./CFS/hawaii_soest_7889_5330_7085?ocnsst" + time + ".nc")
# Out:
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-01-01):1:(1979-02-01)][(1.1):1:(11)][(129):1:(136.4)]
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-02-01):1:(1979-03-01)][(1.1):1:(11)][(129):1:(136.4)]
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-03-01):1:(1979-04-01)][(1.1):1:(11)][(129):1:(136.4)]
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-04-01):1:(1979-05-01)][(1.1):1:(11)][(129):1:(136.4)]
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-05-01):1:(1979-06-01)][(1.1):1:(11)][(129):1:(136.4)]
# http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_7889_5330_7085.nc?ocnsst[(1979-06-01):1:(1979-07-01)][(1.1):1:(11)][(129):1:(136.4)]
# ...

# %%
if not os.path.exists("./CRW"):
    os.makedirs("./CRW")
name = "./CRW/NOAA_Coral_Reef_Watch_Degree_Heating_Week_Daily_5-km"
start = datetime.date(1985, 4, 1) 
end = datetime.date(2023,6,29)

prev = None

# coral_head = "https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SEAICE%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SST%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY_mask%5B(" +"1985-04-01"+ "T12:00:00Z):1:("+"2023-06-29"+"T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D"

# coral_head = "https://pae-paha.pacioos.hawaii.edu/thredds/ncss/dhw_5km?var=CRW_BAA&var=CRW_BAA_7D_MAX&var=CRW_DHW&var=CRW_HOTSPOT&var=CRW_SST&var=CRW_SSTANOMALY&north=11&west=129&east=136.4&south=1.1&disableLLSubset=on&disableProjSubset=on&horizStride=1&"
while (start <= end):
    
    prev = start
    start += relativedelta(months=+3)
    if start > end:
        break
    if prev < datetime.date(1996, 7, 1):
        continue
    time_range = "(" + prev.strftime("%Y-%m-%d") + "T12:00:00Z):1:(" + start.strftime("%Y-%m-%d") + "T12:00:00Z)"
    coral_reef = ("https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B"+
    time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_mask%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX_mask%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW_mask%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT_mask%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SEAICE%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SST%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY_mask%5B"
    + time_range +
    "%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D")
    
#     print(coral_reef)
    urllib.request.urlretrieve(coral_reef,
                           name + "[" + prev.strftime("%Y-%m-%d") + "T12%3A00%3A00Z" +"]["+  start.strftime("%Y-%m-%d")+ "T12%3A00%3A00Z" + "]" + ".nc")
    print(prev, start)
    
time_range = "(" + prev.strftime("%Y-%m-%d") + "T12:00:00Z):1:(" + end.strftime("%Y-%m-%d") + "T12:00:00Z)"
coral_reef = ("https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B"+
time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_mask%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX_mask%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW_mask%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT_mask%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SEAICE%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SST%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY_mask%5B"
+ time_range +
"%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D")
urllib.request.urlretrieve(coral_reef,
                           name + "[" + prev.strftime("%Y-%m-%d") + "T12%3A00%3A00Z" +"]["+  start.strftime("%Y-%m-%d")+ "T12%3A00%3A00Z" + "]" + ".nc")
print(prev, end)
# Out:
# 1996-07-01 1996-10-01
# 1996-10-01 1997-01-01
# 1997-01-01 1997-04-01
# 1997-04-01 1997-07-01
# 1997-07-01 1997-10-01
# 1997-10-01 1998-01-01
# 1998-01-01 1998-04-01
# 1998-04-01 1998-07-01
# 1998-07-01 1998-10-01
# 1998-10-01 1999-01-01
# 1999-01-01 1999-04-01
# 1999-04-01 1999-07-01
# 1999-07-01 1999-10-01
# 1999-10-01 2000-01-01
# 2000-01-01 2000-04-01
# 2000-04-01 2000-07-01
# 2000-07-01 2000-10-01
# 2000-10-01 2001-01-01
# 2001-01-01 2001-04-01
# 2001-04-01 2001-07-01
# 2001-07-01 2001-10-01
# 2001-10-01 2002-01-01
# 2002-01-01 2002-04-01
# 2002-04-01 2002-07-01
# 2002-07-01 2002-10-01
# 2002-10-01 2003-01-01
# 2003-01-01 2003-04-01
# 2003-04-01 2003-07-01
# 2003-07-01 2003-10-01
# 2003-10-01 2004-01-01
# 2004-01-01 2004-04-01
# 2004-04-01 2004-07-01
# 2004-07-01 2004-10-01
# 2004-10-01 2005-01-01
# 2005-01-01 2005-04-01
# 2005-04-01 2005-07-01
# 2005-07-01 2005-10-01
# 2005-10-01 2006-01-01
# 2006-01-01 2006-04-01
# 2006-04-01 2006-07-01
# 2006-07-01 2006-10-01
# ...

# %%
filtered = df[(df["latitude"]>= 0.99)&
                                    (df["latitude"]<=14.01)&(df["longitude"]<=140.51)&
                                    (df["longitude"]>=127.49)]

# %% [markdown]
# (1.5):1:(12)%5D%5B(129):1:(137.1)
# (0.99):1:(14.01)%5D%5B(127.49):1:(140.51)

# %%
if not os.path.exists("./CRW/box"):
    os.makedirs("./CRW/box")
name = "./CRW/box/BOX_NOAA_Coral_Reef_Watch_Degree_Heating_Week_Daily_5-km"
start = datetime.date(1985, 4, 1) 
end = datetime.date(2023,6,29)

prev = None

# coral_head = "https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_BAA_7D_MAX_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_DHW_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_HOTSPOT_mask%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SEAICE%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SST%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY%5B(1985-04-01T12:00:00Z):1:(2023-06-29T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D,CRW_SSTANOMALY_mask%5B(" +"1985-04-01"+ "T12:00:00Z):1:("+"2023-06-29"+"T12:00:00Z)%5D%5B(1.5):1:(12)%5D%5B(129):1:(137.1)%5D"

# coral_head = "https://pae-paha.pacioos.hawaii.edu/thredds/ncss/dhw_5km?var=CRW_BAA&var=CRW_BAA_7D_MAX&var=CRW_DHW&var=CRW_HOTSPOT&var=CRW_SST&var=CRW_SSTANOMALY&north=11&west=129&east=136.4&south=1.1&disableLLSubset=on&disableProjSubset=on&horizStride=1&"
while (start <= end):
    
    prev = start
    start += relativedelta(months=+3)
    if start > end:
        break
    if prev < datetime.date(1996, 7, 1):
        continue
    if "BOX_NOAA_Coral_Reef_Watch_Degree_Heating_Week_Daily_5-km[" + prev.strftime("%Y-%m-%d") + "T12%3A00%3A00Z" +"]["+  start.strftime("%Y-%m-%d")+ "T12%3A00%3A00Z" + "]" + ".nc" not in os.listdir("./CRW/box/"):
    
        time_range = "(" + prev.strftime("%Y-%m-%d") + "T12:00:00Z):1:(" + start.strftime("%Y-%m-%d") + "T12:00:00Z)"
        coral_reef = ("https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B"+
        time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_mask%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_7D_MAX%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_7D_MAX_mask%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_DHW%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_DHW_mask%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_HOTSPOT%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_HOTSPOT_mask%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SEAICE%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SST%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SSTANOMALY%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SSTANOMALY_mask%5B"
        + time_range +
        "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D")

    #     print(coral_reef)
        urllib.request.urlretrieve(coral_reef,
                               name + "[" + prev.strftime("%Y-%m-%d") + "T12%3A00%3A00Z" +"]["+  start.strftime("%Y-%m-%d")+ "T12%3A00%3A00Z" + "]" + ".nc")
        print(prev, start)
    
time_range = "(" + prev.strftime("%Y-%m-%d") + "T12:00:00Z):1:(" + end.strftime("%Y-%m-%d") + "T12:00:00Z)"
coral_reef = ("https://pae-paha.pacioos.hawaii.edu/erddap/griddap/dhw_5km.nc?CRW_BAA%5B"+
    time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_mask%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_7D_MAX%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_BAA_7D_MAX_mask%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_DHW%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_DHW_mask%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_HOTSPOT%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_HOTSPOT_mask%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SEAICE%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SST%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SSTANOMALY%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D,CRW_SSTANOMALY_mask%5B"
    + time_range +
    "%5D%5B(0.99):1:(14.01)%5D%5B(127.49):1:(140.51)%5D")
urllib.request.urlretrieve(coral_reef,
                           name + "[" + prev.strftime("%Y-%m-%d") + "T12%3A00%3A00Z" +"]["+  start.strftime("%Y-%m-%d")+ "T12%3A00%3A00Z" + "]" + ".nc")
print(prev, end)
# Out:
# 2002-04-01 2002-07-01
# 2002-07-01 2002-10-01
# 2002-10-01 2003-01-01
# 2003-01-01 2003-04-01
# 2003-04-01 2003-07-01
# 2003-07-01 2003-10-01
# 2003-10-01 2004-01-01
# 2004-01-01 2004-04-01
# 2004-04-01 2004-07-01
# 2004-07-01 2004-10-01
# 2004-10-01 2005-01-01
# 2005-01-01 2005-04-01
# 2005-04-01 2005-07-01
# 2005-07-01 2005-10-01
# 2005-10-01 2006-01-01
# 2006-01-01 2006-04-01
# 2006-04-01 2006-07-01
# 2006-07-01 2006-10-01
# 2006-10-01 2007-01-01
# 2007-01-01 2007-04-01
# 2007-04-01 2007-07-01
# 2007-07-01 2007-10-01
